# %%
from datasets import get_dataloaders, get_embed
import types

# %%
fake_args = types.SimpleNamespace(
    data_dir="/vol/biodata/data/Mammo/EMBED/pngs/1024x768",
    csv_filepath="EMBED_meta.csv",
    cache_dir=None,
    parents=["age", "view", "density", "scanner", "cview"],
    domain=None,
    model=None,
    exclude_cviews=1,
    hold_out_model_5=True,
    prop_train=1.0,
    num_valid_patients=600,
    split_seed=33,
    img_height=512,
    img_width=384,
    in_channels=1,
    bs=4,
    num_workers=0,
    prefetch_factor=2,
    seed=0,
)

# %%
datasets = get_embed(fake_args)
# print({k: len(v) for k, v in datasets.items()})

# dataloaders = get_dataloaders(fake_args, datasets)
# print(dataloaders)

# batch = next(iter(dataloaders["train"]))
# print(batch.keys())
# print("x shape:", batch["x"].shape)
# print("shortpath:", batch["shortpath"][:2])
# print("pa:", batch["pa"])
