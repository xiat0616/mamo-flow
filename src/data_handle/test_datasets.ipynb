# %%
import sys
sys.path.append("../../")
from src.data_handle.datasets import get_dataloaders, get_embed, DatasetConfig, DataLoaderConfig

# %%
dataset_cfg = DatasetConfig(
    data_dir="/vol/biodata/data/Mammo/EMBED/pngs/1024x768",
    split_dir="/vol/biomedic3/tx1215/mamo-flow/assets/embed_splits_v1",
    parents=["age", "view", "density", "scanner", "cview"],
    img_height=512,
    img_width=384,
    img_channels=1,
)
loader_cfg = DataLoaderConfig(
    bs=12,
    num_workers=12,
    prefetch_factor=2,
    seed=0,
)

# %%
import pandas as pd
from src.data_handle.datasets import load_split_csvs

split_dfs = load_split_csvs(dataset_cfg.split_dir)
for split, df in split_dfs.items():
    print(f"\n--- {split} ({len(df)} rows) ---")
    print(f"Columns: {list(df.columns)}")
    if "tissueden" in df.columns:
        print(f"density: {df['tissueden'].value_counts(normalize=True).to_dict()}")
    if "ViewPosition" in df.columns:
        print(f"view:    {df['ViewPosition'].value_counts(normalize=True).to_dict()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 from src.data_handle.datasets import load_split_csvs
#       3
# ----> 4 split_dfs = load_split_csvs(dataset_cfg.split_dir)
#       5 for split, df in split_dfs.items():
#       6     print(f"\n--- {split} ({len(df)} rows) ---")
#       7     print(f"Columns: {list(df.columns)}")
#
# File /vol/biomedic3/tx1215/mamo-flow/src/data_handle/../../src/data_handle/datasets.py:121, in load_split_csvs(split_dir)
#     119     path = split_dir / f"{split}.csv"
#     120     if not path.exists():
# --> 121         raise FileNotFoundError(f"Missing split CSV: {path}")
#     122     split_dfs[split] = pd.read_csv(path, low_memory=False).reset_index(drop=True)
#     124 return split_dfs
#
# FileNotFoundError: Missing split CSV: /vol/biomedic3/tx1215/mamo-flow/assets/splits/train.csv

# %%
datasets = get_embed(dataset_cfg)
print({k: len(v) for k, v in datasets.items()})

dataloaders = get_dataloaders(loader_cfg, datasets)
print(dataloaders)

batch = next(iter(dataloaders["train"]))
print(batch.keys())
print("x shape:", batch["x"].shape)
print("x range:", batch["x"].min(), batch["x"].max())
# print("shortpath:", batch["shortpath"][:2])
print("pa:", batch["pa"].keys())

# %%
for k in batch["pa"].keys():
    print(f"pa[{k}] shape: {batch['pa'][k].shape}, range: {batch['pa'][k].min()} - {batch['pa'][k].max()}")
